# %%
import	 requests
url="https://ru42.voyna-plemyon.ru/game.php"

data = {
	"village":"5562",
	"screen":"place",
	"try":"confirm",
	"5f63d5bf73a735a5afa8c4":"4dcbe0065f63d5",
	"template_id":"",
	"source_village":"5562",
	"spear":"8",
	"sword":"8",
	"axe":"",
	"archer":"",
	"spy":"",
	"light":"",
	"marcher":"",
	"heavy":"",
	"ram":"",
	"catapult":"",
	"knight":"",
	"snob":"",
	"x":"447",
	"y":"553",
	"target_type":"coord",
	"input":"447|553",
	"attack":"Атака"
}

cookies = {
	"cid":"2001072207",
	"portal_tid":"1471678585599-63567",
	"user":"MrZhigan",
	"password":"af2b2e5dd598b806128e408c5b7873ff7b7634b8",
	"no_remember":"0",
	"portal_data":"portal_tid=1471678585599-63567",
	"__utmt":"1",
	"__utma":"189530924.2098698103.1471678586.1472122514.1472760504.3",
	"__utmb":"189530924.1.10.1472760504",
	"__utmc":"189530924",
	"__utmz":"189530924.1471678586.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none)",
	"_dc_gtm_UA-50308805-1":"1",
	"_dc_gtm_UA-1897727-9":"1",
	"sid":"0%3A3cce22765c0a",
	"ref1720916":"start",
	"_ga":"GA1.2.2098698103.1471678586",
	"__utma":"236281090.2098698103.1471678586.1472122518.1472760508.3",
	"__utmb":"236281090.14.10.1472760508",
	"__utmc":"236281090",
	"__utmz":"236281090.1472760508.3.3.utmcsr=voyna-plemyon.ru|utmccn=(referral)|utmcmd=referral|utmcct=/",
	"websocket_available":"true",
	"global_village_id":"5562",
	"mobile":"0"
}

print requests.post(url,data=data, cookies=cookies).text
# Out:
# <!DOCTYPE HTML>
# <html>
# <head>
# 	<title>Tryhard (445|548) - Война племён - Мир 42</title>
# 	<meta http-equiv="content-type" content="text/html; charset=UTF-8" />
# 	<link id="favicon" rel="shortcut icon"  href="/favicon.ico" />
#
# 	<link rel="stylesheet" type="text/css" href="https://dsru.innogamescdn.com/assets/ru42/b3eea96172e293472861c9268bb76ea9/merged/game.css" />
#
# 			<link rel="stylesheet" type="text/css" href="https://dsru.innogamescdn.com/assets/ru42/2bce2c5f462059ce6f485030e5b21cfd/css/game/overview.css" />
#
#
# 	<script type="text/javascript" src="https://dsru.innogamescdn.com/assets/ru42/88e6ec2bbb4e0f2d4c47d9401c77c690/merged/game.js"></script>
#
# 			<script type="text/javascript" src="https://dsru.innogamescdn.com/assets/ru42/f83df720ebd356f006352c2ba916e959/js/game/upgrade_building.js"></script>
#
# 			<script type="text/javascript" src="https://dsru.innogamescdn.com/assets/ru42/cd6f538d17e6270e0205ddbbb9e6ec53/js/game/VillageOverview.js"></script>
#
#
#
#
# ...
